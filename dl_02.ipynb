# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 10 # Changed epochs to 10
w,b = np.zeros(2),0

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  0 <- at epoch 0
# [0. 0.] -1
# error :  1 <- at epoch 0
# [1. 1.] 0
# error :  -1 <- at epoch 1
# [1. 1.] -1
# error :  -1 <- at epoch 1
# [1. 0.] -2
# error :  0 <- at epoch 1
# [1. 0.] -2
# error :  1 <- at epoch 1
# [2. 1.] -1
# error :  0 <- at epoch 2
# [2. 1.] -1
# error :  -1 <- at epoch 2
# [2. 0.] -2
# error :  -1 <- at epoch 2
# [1. 0.] -3
# error :  1 <- at epoch 2
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  0 <- at epoch 3
# [2. 1.] -2
# error :  -1 <- at epoch 3
# [1. 1.] -3
# error :  1 <- at epoch 3
# [2. 2.] -2
# error :  0 <- at epoch 4
# [2. 2.] -2
# error :  -1 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 4
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 5
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 6
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 7
# [2. 1.] -3
# error :  0 <- at epoch 8
# [2. 1.] -3
# error :  0 <- at epoch 8
# [2. 1.] -3
# error :  0 <- at epoch 8
# [2. 1.] -3
# error :  0 <- at epoch 8
# [2. 1.] -3
# error :  0 <- at epoch 9
# [2. 1.] -3
# error :  0 <- at epoch 9
# [2. 1.] -3
# error :  0 <- at epoch 9
# [2. 1.] -3
# error :  0 <- at epoch 9
# [2. 1.] -3

# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 10
w,b = [1,-4],2

for _ in range(epochs):
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
# Out:
# error :  -1 <- at epoch 0
# [ 1 -4] 1
# error :  0 <- at epoch 0
# [ 1 -4] 1
# error :  -1 <- at epoch 0
# [ 0 -4] 0
# error :  1 <- at epoch 0
# [ 1 -3] 1
# error :  -1 <- at epoch 1
# [ 1 -3] 0
# error :  0 <- at epoch 1
# [ 1 -3] 0
# error :  -1 <- at epoch 1
# [ 0 -3] -1
# error :  1 <- at epoch 1
# [ 1 -2] 0
# error :  -1 <- at epoch 2
# [ 1 -2] -1
# error :  0 <- at epoch 2
# [ 1 -2] -1
# error :  -1 <- at epoch 2
# [ 0 -2] -2
# error :  1 <- at epoch 2
# [ 1 -1] -1
# error :  0 <- at epoch 3
# [ 1 -1] -1
# error :  0 <- at epoch 3
# [ 1 -1] -1
# error :  -1 <- at epoch 3
# [ 0 -1] -2
# error :  1 <- at epoch 3
# [1 0] -1
# error :  0 <- at epoch 4
# [1 0] -1
# error :  0 <- at epoch 4
# [1 0] -1
# error :  -1 <- at epoch 4
# [0 0] -2
# error :  1 <- at epoch 4
# [1 1] -1
# error :  0 <- at epoch 5
# [1 1] -1
# error :  -1 <- at epoch 5
# [1 0] -2
# error :  0 <- at epoch 5
# [1 0] -2
# error :  1 <- at epoch 5
# [2 1] -1
# error :  0 <- at epoch 6
# [2 1] -1
# error :  -1 <- at epoch 6
# [2 0] -2
# error :  -1 <- at epoch 6
# [1 0] -3
# error :  1 <- at epoch 6
# [2 1] -2
# error :  0 <- at epoch 7
# [2 1] -2
# error :  0 <- at epoch 7
# [2 1] -2
# error :  -1 <- at epoch 7
# [1 1] -3
# error :  1 <- at epoch 7
# [2 2] -2
# error :  0 <- at epoch 8
# [2 2] -2
# error :  -1 <- at epoch 8
# [2 1] -3
# error :  0 <- at epoch 8
# [2 1] -3
# error :  0 <- at epoch 8
# [2 1] -3
# error :  0 <- at epoch 9
# [2 1] -3
# error :  0 <- at epoch 9
# [2 1] -3
# error :  0 <- at epoch 9
# [2 1] -3
# error :  0 <- at epoch 9
# [2 1] -3

# %%
import numpy as np
# for AND gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,0,0,1])
epochs = 10
w,b = [1,-2],0

for _ in range(epochs):
  total_error_in_epoch = 0 # Initialize total error for the current epoch
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E) # Accumulate absolute error
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break # Stop training if no errors occurred in the epoch
# Out:
# error :  -1 <- at epoch 0
# [ 1 -2] -1
# error :  0 <- at epoch 0
# [ 1 -2] -1
# error :  -1 <- at epoch 0
# [ 0 -2] -2
# error :  1 <- at epoch 0
# [ 1 -1] -1
# error :  0 <- at epoch 1
# [ 1 -1] -1
# error :  0 <- at epoch 1
# [ 1 -1] -1
# error :  -1 <- at epoch 1
# [ 0 -1] -2
# error :  1 <- at epoch 1
# [1 0] -1
# error :  0 <- at epoch 2
# [1 0] -1
# error :  0 <- at epoch 2
# [1 0] -1
# error :  -1 <- at epoch 2
# [0 0] -2
# error :  1 <- at epoch 2
# [1 1] -1
# error :  0 <- at epoch 3
# [1 1] -1
# error :  -1 <- at epoch 3
# [1 0] -2
# error :  0 <- at epoch 3
# [1 0] -2
# error :  1 <- at epoch 3
# [2 1] -1
# error :  0 <- at epoch 4
# [2 1] -1
# error :  -1 <- at epoch 4
# [2 0] -2
# error :  -1 <- at epoch 4
# [1 0] -3
# error :  1 <- at epoch 4
# [2 1] -2
# error :  0 <- at epoch 5
# [2 1] -2
# error :  0 <- at epoch 5
# [2 1] -2
# error :  -1 <- at epoch 5
# [1 1] -3
# error :  1 <- at epoch 5
# [2 2] -2
# error :  0 <- at epoch 6
# [2 2] -2
# error :  -1 <- at epoch 6
# [2 1] -3
# error :  0 <- at epoch 6
# [2 1] -3
# error :  0 <- at epoch 6
# [2 1] -3
# error :  0 <- at epoch 7
# [2 1] -3
# error :  0 <- at epoch 7
# [2 1] -3
# error :  0 <- at epoch 7
# [2 1] -3
# error :  0 <- at epoch 7
# [2 1] -3
# Converged at epoch 7. No errors found.

# %%
import numpy as np
# for OR gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,1]) # Changed y_list for OR gate
epochs = 10
w,b = [1,-5],2

for _ in range(epochs):
  total_error_in_epoch = 0
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E)
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break
# Out:
# error :  -1 <- at epoch 0
# [ 1 -5] 1
# error :  1 <- at epoch 0
# [ 1 -4] 2
# error :  0 <- at epoch 0
# [ 1 -4] 2
# error :  1 <- at epoch 0
# [ 2 -3] 3
# error :  -1 <- at epoch 1
# [ 2 -3] 2
# error :  1 <- at epoch 1
# [ 2 -2] 3
# error :  0 <- at epoch 1
# [ 2 -2] 3
# error :  0 <- at epoch 1
# [ 2 -2] 3
# error :  -1 <- at epoch 2
# [ 2 -2] 2
# error :  0 <- at epoch 2
# [ 2 -2] 2
# error :  0 <- at epoch 2
# [ 2 -2] 2
# error :  0 <- at epoch 2
# [ 2 -2] 2
# error :  -1 <- at epoch 3
# [ 2 -2] 1
# error :  1 <- at epoch 3
# [ 2 -1] 2
# error :  0 <- at epoch 3
# [ 2 -1] 2
# error :  0 <- at epoch 3
# [ 2 -1] 2
# error :  -1 <- at epoch 4
# [ 2 -1] 1
# error :  0 <- at epoch 4
# [ 2 -1] 1
# error :  0 <- at epoch 4
# [ 2 -1] 1
# error :  0 <- at epoch 4
# [ 2 -1] 1
# error :  -1 <- at epoch 5
# [ 2 -1] 0
# error :  1 <- at epoch 5
# [2 0] 1
# error :  0 <- at epoch 5
# [2 0] 1
# error :  0 <- at epoch 5
# [2 0] 1
# error :  -1 <- at epoch 6
# [2 0] 0
# error :  0 <- at epoch 6
# [2 0] 0
# error :  0 <- at epoch 6
# [2 0] 0
# error :  0 <- at epoch 6
# [2 0] 0
# error :  -1 <- at epoch 7
# [2 0] -1
# error :  1 <- at epoch 7
# [2 1] 0
# error :  0 <- at epoch 7
# [2 1] 0
# error :  0 <- at epoch 7
# [2 1] 0
# error :  -1 <- at epoch 8
# [2 1] -1
# error :  0 <- at epoch 8
# [2 1] -1
# error :  0 <- at epoch 8
# [2 1] -1
# error :  0 <- at epoch 8
# [2 1] -1
# error :  0 <- at epoch 9
# [2 1] -1
# error :  0 <- at epoch 9
# [2 1] -1
# error :  0 <- at epoch 9
# [2 1] -1
# error :  0 <- at epoch 9
# [2 1] -1
# Converged at epoch 9. No errors found.

# %%
import numpy as np
# for XOR gate (Input/Output)
x_list = np.array([[0,0],[0,1],[1,0],[1,1]])
y_list = np.array([0,1,1,0]) # Changed y_list for XOR gate
epochs = 100 # Increased epochs to clearly show non-convergence
w,b = [5,-7],2

for _ in range(epochs):
  total_error_in_epoch = 0
  for x,y in zip(x_list,y_list):
    z = np.dot(x,w) + b
    ### condition area for y_pred
    y_pred = 1 if z >= 0 else 0
    E = y - y_pred
    total_error_in_epoch += abs(E)
    print("error : ",E,"<- at epoch",_)
    w += E*x
    b += E
    print(w,b)
  if total_error_in_epoch == 0:
    print(f"Converged at epoch {_}. No errors found.")
    break
# Out:
# error :  -1 <- at epoch 0
# [ 5 -7] 1
# error :  1 <- at epoch 0
# [ 5 -6] 2
# error :  0 <- at epoch 0
# [ 5 -6] 2
# error :  -1 <- at epoch 0
# [ 4 -7] 1
# error :  -1 <- at epoch 1
# [ 4 -7] 0
# error :  1 <- at epoch 1
# [ 4 -6] 1
# error :  0 <- at epoch 1
# [ 4 -6] 1
# error :  0 <- at epoch 1
# [ 4 -6] 1
# error :  -1 <- at epoch 2
# [ 4 -6] 0
# error :  1 <- at epoch 2
# [ 4 -5] 1
# error :  0 <- at epoch 2
# [ 4 -5] 1
# error :  -1 <- at epoch 2
# [ 3 -6] 0
# error :  -1 <- at epoch 3
# [ 3 -6] -1
# error :  1 <- at epoch 3
# [ 3 -5] 0
# error :  0 <- at epoch 3
# [ 3 -5] 0
# error :  0 <- at epoch 3
# [ 3 -5] 0
# error :  -1 <- at epoch 4
# [ 3 -5] -1
# error :  1 <- at epoch 4
# [ 3 -4] 0
# error :  0 <- at epoch 4
# [ 3 -4] 0
# error :  0 <- at epoch 4
# [ 3 -4] 0
# error :  -1 <- at epoch 5
# [ 3 -4] -1
# error :  1 <- at epoch 5
# [ 3 -3] 0
# error :  0 <- at epoch 5
# [ 3 -3] 0
# error :  -1 <- at epoch 5
# [ 2 -4] -1
# error :  0 <- at epoch 6
# [ 2 -4] -1
# error :  1 <- at epoch 6
# [ 2 -3] 0
# error :  0 <- at epoch 6
# [ 2 -3] 0
# error :  0 <- at epoch 6
# [ 2 -3] 0
# error :  -1 <- at epoch 7
# [ 2 -3] -1
# error :  1 <- at epoch 7
# [ 2 -2] 0
# error :  0 <- at epoch 7
# [ 2 -2] 0
# error :  -1 <- at epoch 7
# [ 1 -3] -1
# error :  0 <- at epoch 8
# [ 1 -3] -1
# error :  1 <- at epoch 8
# [ 1 -2] 0
# error :  0 <- at epoch 8
# [ 1 -2] 0
# error :  0 <- at epoch 8
# [ 1 -2] 0
# error :  -1 <- at epoch 9
# [ 1 -2] -1
# error :  1 <- at epoch 9
# [ 1 -1] 0
# error :  0 <- at epoch 9
# [ 1 -1] 0
# error :  -1 <- at epoch 9
# [ 0 -2] -1
# error :  0 <- at epoch 10
# [ 0 -2] -1
# error :  1 <- at epoch 10
# [ 0 -1] 0
# error :  0 <- at epoch 10
# [ 0 -1] 0
# error :  0 <- at epoch 10
# [ 0 -1] 0
# error :  -1 <- at epoch 11
# [ 0 -1] -1
# error :  1 <- at epoch 11
# [0 0] 0
# error :  0 <- at epoch 11
# [0 0] 0
# error :  -1 <- at epoch 11
# [-1 -1] -1
# error :  0 <- at epoch 12
# [-1 -1] -1
# error :  1 <- at epoch 12
# [-1  0] 0
# error :  1 <- at epoch 12
# [0 0] 1
# error :  -1 <- at epoch 12
# [-1 -1] 0
# error :  -1 <- at epoch 13
# [-1 -1] -1
# error :  1 <- at epoch 13
# [-1  0] 0
# error :  1 <- at epoch 13
# [0 0] 1
# error :  -1 <- at epoch 13
# [-1 -1] 0
# error :  -1 <- at epoch 14
# [-1 -1] -1
# error :  1 <- at epoch 14
# [-1  0] 0
# error :  1 <- at epoch 14
# [0 0] 1
# error :  -1 <- at epoch 14
# [-1 -1] 0
# error :  -1 <- at epoch 15
# [-1 -1] -1
# error :  1 <- at epoch 15
# [-1  0] 0
# error :  1 <- at epoch 15
# [0 0] 1
# error :  -1 <- at epoch 15
# [-1 -1] 0
# error :  -1 <- at epoch 16
# [-1 -1] -1
# error :  1 <- at epoch 16
# [-1  0] 0
# error :  1 <- at epoch 16
# [0 0] 1
# error :  -1 <- at epoch 16
# [-1 -1] 0
# error :  -1 <- at epoch 17
# [-1 -1] -1
# error :  1 <- at epoch 17
# [-1  0] 0
# error :  1 <- at epoch 17
# [0 0] 1
# error :  -1 <- at epoch 17
# [-1 -1] 0
# error :  -1 <- at epoch 18
# [-1 -1] -1
# error :  1 <- at epoch 18
# [-1  0] 0
# error :  1 <- at epoch 18
# [0 0] 1
# error :  -1 <- at epoch 18
# [-1 -1] 0
# error :  -1 <- at epoch 19
# [-1 -1] -1
# error :  1 <- at epoch 19
# [-1  0] 0
# error :  1 <- at epoch 19
# [0 0] 1
# error :  -1 <- at epoch 19
# [-1 -1] 0
# error :  -1 <- at epoch 20
# [-1 -1] -1
# error :  1 <- at epoch 20
# [-1  0] 0
# error :  1 <- at epoch 20
# [0 0] 1
# error :  -1 <- at epoch 20
# [-1 -1] 0
# error :  -1 <- at epoch 21
# [-1 -1] -1
# error :  1 <- at epoch 21
# [-1  0] 0
# error :  1 <- at epoch 21
# [0 0] 1
# error :  -1 <- at epoch 21
# [-1 -1] 0
# error :  -1 <- at epoch 22
# [-1 -1] -1
# error :  1 <- at epoch 22
# [-1  0] 0
# error :  1 <- at epoch 22
# [0 0] 1
# error :  -1 <- at epoch 22
# [-1 -1] 0
# error :  -1 <- at epoch 23
# [-1 -1] -1
# error :  1 <- at epoch 23
# [-1  0] 0
# error :  1 <- at epoch 23
# [0 0] 1
# error :  -1 <- at epoch 23
# [-1 -1] 0
# error :  -1 <- at epoch 24
# [-1 -1] -1
# error :  1 <- at epoch 24
# [-1  0] 0
# error :  1 <- at epoch 24
# [0 0] 1
# error :  -1 <- at epoch 24
# [-1 -1] 0
# error :  -1 <- at epoch 25
# [-1 -1] -1
# error :  1 <- at epoch 25
# [-1  0] 0
# error :  1 <- at epoch 25
# [0 0] 1
# error :  -1 <- at epoch 25
# [-1 -1] 0
# error :  -1 <- at epoch 26
# [-1 -1] -1
# error :  1 <- at epoch 26
# [-1  0] 0
# error :  1 <- at epoch 26
# [0 0] 1
# error :  -1 <- at epoch 26
# [-1 -1] 0
# error :  -1 <- at epoch 27
# [-1 -1] -1
# error :  1 <- at epoch 27
# [-1  0] 0
# error :  1 <- at epoch 27
# [0 0] 1
# error :  -1 <- at epoch 27
# [-1 -1] 0
# error :  -1 <- at epoch 28
# [-1 -1] -1
# error :  1 <- at epoch 28
# [-1  0] 0
# error :  1 <- at epoch 28
# [0 0] 1
# error :  -1 <- at epoch 28
# [-1 -1] 0
# error :  -1 <- at epoch 29
# [-1 -1] -1
# error :  1 <- at epoch 29
# [-1  0] 0
# error :  1 <- at epoch 29
# [0 0] 1
# error :  -1 <- at epoch 29
# [-1 -1] 0
# error :  -1 <- at epoch 30
# [-1 -1] -1
# error :  1 <- at epoch 30
# [-1  0] 0
# error :  1 <- at epoch 30
# [0 0] 1
# error :  -1 <- at epoch 30
# [-1 -1] 0
# error :  -1 <- at epoch 31
# [-1 -1] -1
# error :  1 <- at epoch 31
# [-1  0] 0
# error :  1 <- at epoch 31
# [0 0] 1
# error :  -1 <- at epoch 31
# [-1 -1] 0
# error :  -1 <- at epoch 32
# [-1 -1] -1
# error :  1 <- at epoch 32
# [-1  0] 0
# error :  1 <- at epoch 32
# [0 0] 1
# error :  -1 <- at epoch 32
# [-1 -1] 0
# error :  -1 <- at epoch 33
# [-1 -1] -1
# error :  1 <- at epoch 33
# [-1  0] 0
# error :  1 <- at epoch 33
# [0 0] 1
# error :  -1 <- at epoch 33
# [-1 -1] 0
# error :  -1 <- at epoch 34
# [-1 -1] -1
# error :  1 <- at epoch 34
# [-1  0] 0
# error :  1 <- at epoch 34
# [0 0] 1
# error :  -1 <- at epoch 34
# [-1 -1] 0
# error :  -1 <- at epoch 35
# [-1 -1] -1
# error :  1 <- at epoch 35
# [-1  0] 0
# error :  1 <- at epoch 35
# [0 0] 1
# error :  -1 <- at epoch 35
# [-1 -1] 0
# error :  -1 <- at epoch 36
# [-1 -1] -1
# error :  1 <- at epoch 36
# [-1  0] 0
# error :  1 <- at epoch 36
# [0 0] 1
# error :  -1 <- at epoch 36
# [-1 -1] 0
# error :  -1 <- at epoch 37
# [-1 -1] -1
# error :  1 <- at epoch 37
# [-1  0] 0
# error :  1 <- at epoch 37
# [0 0] 1
# error :  -1 <- at epoch 37
# [-1 -1] 0
# error :  -1 <- at epoch 38
# [-1 -1] -1
# error :  1 <- at epoch 38
# [-1  0] 0
# error :  1 <- at epoch 38
# [0 0] 1
# error :  -1 <- at epoch 38
# [-1 -1] 0
# error :  -1 <- at epoch 39
# [-1 -1] -1
# error :  1 <- at epoch 39
# [-1  0] 0
# error :  1 <- at epoch 39
# [0 0] 1
# error :  -1 <- at epoch 39
# [-1 -1] 0
# error :  -1 <- at epoch 40
# [-1 -1] -1
# error :  1 <- at epoch 40
# [-1  0] 0
# error :  1 <- at epoch 40
# [0 0] 1
# error :  -1 <- at epoch 40
# [-1 -1] 0
# error :  -1 <- at epoch 41
# [-1 -1] -1
# error :  1 <- at epoch 41
# [-1  0] 0
# error :  1 <- at epoch 41
# [0 0] 1
# error :  -1 <- at epoch 41
# [-1 -1] 0
# error :  -1 <- at epoch 42
# [-1 -1] -1
# error :  1 <- at epoch 42
# [-1  0] 0
# error :  1 <- at epoch 42
# [0 0] 1
# error :  -1 <- at epoch 42
# [-1 -1] 0
# error :  -1 <- at epoch 43
# [-1 -1] -1
# error :  1 <- at epoch 43
# [-1  0] 0
# error :  1 <- at epoch 43
# [0 0] 1
# error :  -1 <- at epoch 43
# [-1 -1] 0
# error :  -1 <- at epoch 44
# [-1 -1] -1
# error :  1 <- at epoch 44
# [-1  0] 0
# error :  1 <- at epoch 44
# [0 0] 1
# error :  -1 <- at epoch 44
# [-1 -1] 0
# error :  -1 <- at epoch 45
# [-1 -1] -1
# error :  1 <- at epoch 45
# [-1  0] 0
# error :  1 <- at epoch 45
# [0 0] 1
# error :  -1 <- at epoch 45
# [-1 -1] 0
# error :  -1 <- at epoch 46
# [-1 -1] -1
# error :  1 <- at epoch 46
# [-1  0] 0
# error :  1 <- at epoch 46
# [0 0] 1
# error :  -1 <- at epoch 46
# [-1 -1] 0
# error :  -1 <- at epoch 47
# [-1 -1] -1
# error :  1 <- at epoch 47
# [-1  0] 0
# error :  1 <- at epoch 47
# [0 0] 1
# error :  -1 <- at epoch 47
# [-1 -1] 0
# error :  -1 <- at epoch 48
# [-1 -1] -1
# error :  1 <- at epoch 48
# [-1  0] 0
# error :  1 <- at epoch 48
# [0 0] 1
# error :  -1 <- at epoch 48
# [-1 -1] 0
# error :  -1 <- at epoch 49
# [-1 -1] -1
# error :  1 <- at epoch 49
# [-1  0] 0
# error :  1 <- at epoch 49
# [0 0] 1
# error :  -1 <- at epoch 49
# [-1 -1] 0
# error :  -1 <- at epoch 50
# [-1 -1] -1
# error :  1 <- at epoch 50
# [-1  0] 0
# error :  1 <- at epoch 50
# [0 0] 1
# error :  -1 <- at epoch 50
# [-1 -1] 0
# error :  -1 <- at epoch 51
# [-1 -1] -1
# error :  1 <- at epoch 51
# [-1  0] 0
# error :  1 <- at epoch 51
# [0 0] 1
# error :  -1 <- at epoch 51
# [-1 -1] 0
# error :  -1 <- at epoch 52
# [-1 -1] -1
# error :  1 <- at epoch 52
# [-1  0] 0
# error :  1 <- at epoch 52
# [0 0] 1
# error :  -1 <- at epoch 52
# [-1 -1] 0
# error :  -1 <- at epoch 53
# [-1 -1] -1
# error :  1 <- at epoch 53
# [-1  0] 0
# error :  1 <- at epoch 53
# [0 0] 1
# error :  -1 <- at epoch 53
# [-1 -1] 0
# error :  -1 <- at epoch 54
# [-1 -1] -1
# error :  1 <- at epoch 54
# [-1  0] 0
# error :  1 <- at epoch 54
# [0 0] 1
# error :  -1 <- at epoch 54
# [-1 -1] 0
# error :  -1 <- at epoch 55
# [-1 -1] -1
# error :  1 <- at epoch 55
# [-1  0] 0
# error :  1 <- at epoch 55
# [0 0] 1
# error :  -1 <- at epoch 55
# [-1 -1] 0
# error :  -1 <- at epoch 56
# [-1 -1] -1
# error :  1 <- at epoch 56
# [-1  0] 0
# error :  1 <- at epoch 56
# [0 0] 1
# error :  -1 <- at epoch 56
# [-1 -1] 0
# error :  -1 <- at epoch 57
# [-1 -1] -1
# error :  1 <- at epoch 57
# [-1  0] 0
# error :  1 <- at epoch 57
# [0 0] 1
# error :  -1 <- at epoch 57
# [-1 -1] 0
# error :  -1 <- at epoch 58
# [-1 -1] -1
# error :  1 <- at epoch 58
# [-1  0] 0
# error :  1 <- at epoch 58
# [0 0] 1
# error :  -1 <- at epoch 58
# [-1 -1] 0
# error :  -1 <- at epoch 59
# [-1 -1] -1
# error :  1 <- at epoch 59
# [-1  0] 0
# error :  1 <- at epoch 59
# [0 0] 1
# error :  -1 <- at epoch 59
# [-1 -1] 0
# error :  -1 <- at epoch 60
# [-1 -1] -1
# error :  1 <- at epoch 60
# [-1  0] 0
# error :  1 <- at epoch 60
# [0 0] 1
# error :  -1 <- at epoch 60
# [-1 -1] 0
# error :  -1 <- at epoch 61
# [-1 -1] -1
# error :  1 <- at epoch 61
# [-1  0] 0
# error :  1 <- at epoch 61
# [0 0] 1
# error :  -1 <- at epoch 61
# [-1 -1] 0
# error :  -1 <- at epoch 62
# [-1 -1] -1
# error :  1 <- at epoch 62
# [-1  0] 0
# error :  1 <- at epoch 62
# [0 0] 1
# error :  -1 <- at epoch 62
# [-1 -1] 0
# error :  -1 <- at epoch 63
# [-1 -1] -1
# error :  1 <- at epoch 63
# [-1  0] 0
# error :  1 <- at epoch 63
# [0 0] 1
# error :  -1 <- at epoch 63
# [-1 -1] 0
# error :  -1 <- at epoch 64
# [-1 -1] -1
# error :  1 <- at epoch 64
# [-1  0] 0
# error :  1 <- at epoch 64
# [0 0] 1
# error :  -1 <- at epoch 64
# [-1 -1] 0
# error :  -1 <- at epoch 65
# [-1 -1] -1
# error :  1 <- at epoch 65
# [-1  0] 0
# error :  1 <- at epoch 65
# [0 0] 1
# error :  -1 <- at epoch 65
# [-1 -1] 0
# error :  -1 <- at epoch 66
# [-1 -1] -1
# error :  1 <- at epoch 66
# [-1  0] 0
# error :  1 <- at epoch 66
# [0 0] 1
# error :  -1 <- at epoch 66
# [-1 -1] 0
# error :  -1 <- at epoch 67
# [-1 -1] -1
# error :  1 <- at epoch 67
# [-1  0] 0
# error :  1 <- at epoch 67
# [0 0] 1
# error :  -1 <- at epoch 67
# [-1 -1] 0
# error :  -1 <- at epoch 68
# [-1 -1] -1
# error :  1 <- at epoch 68
# [-1  0] 0
# error :  1 <- at epoch 68
# [0 0] 1
# error :  -1 <- at epoch 68
# [-1 -1] 0
# error :  -1 <- at epoch 69
# [-1 -1] -1
# error :  1 <- at epoch 69
# [-1  0] 0
# error :  1 <- at epoch 69
# [0 0] 1
# error :  -1 <- at epoch 69
# [-1 -1] 0
# error :  -1 <- at epoch 70
# [-1 -1] -1
# error :  1 <- at epoch 70
# [-1  0] 0
# error :  1 <- at epoch 70
# [0 0] 1
# error :  -1 <- at epoch 70
# [-1 -1] 0
# error :  -1 <- at epoch 71
# [-1 -1] -1
# error :  1 <- at epoch 71
# [-1  0] 0
# error :  1 <- at epoch 71
# [0 0] 1
# error :  -1 <- at epoch 71
# [-1 -1] 0
# error :  -1 <- at epoch 72
# [-1 -1] -1
# error :  1 <- at epoch 72
# [-1  0] 0
# error :  1 <- at epoch 72
# [0 0] 1
# error :  -1 <- at epoch 72
# [-1 -1] 0
# error :  -1 <- at epoch 73
# [-1 -1] -1
# error :  1 <- at epoch 73
# [-1  0] 0
# error :  1 <- at epoch 73
# [0 0] 1
# error :  -1 <- at epoch 73
# [-1 -1] 0
# error :  -1 <- at epoch 74
# [-1 -1] -1
# error :  1 <- at epoch 74
# [-1  0] 0
# error :  1 <- at epoch 74
# [0 0] 1
# error :  -1 <- at epoch 74
# [-1 -1] 0
# error :  -1 <- at epoch 75
# [-1 -1] -1
# error :  1 <- at epoch 75
# [-1  0] 0
# error :  1 <- at epoch 75
# [0 0] 1
# error :  -1 <- at epoch 75
# [-1 -1] 0
# error :  -1 <- at epoch 76
# [-1 -1] -1
# error :  1 <- at epoch 76
# [-1  0] 0
# error :  1 <- at epoch 76
# [0 0] 1
# error :  -1 <- at epoch 76
# [-1 -1] 0
# error :  -1 <- at epoch 77
# [-1 -1] -1
# error :  1 <- at epoch 77
# [-1  0] 0
# error :  1 <- at epoch 77
# [0 0] 1
# error :  -1 <- at epoch 77
# [-1 -1] 0
# error :  -1 <- at epoch 78
# [-1 -1] -1
# error :  1 <- at epoch 78
# [-1  0] 0
# error :  1 <- at epoch 78
# [0 0] 1
# error :  -1 <- at epoch 78
# [-1 -1] 0
# error :  -1 <- at epoch 79
# [-1 -1] -1
# error :  1 <- at epoch 79
# [-1  0] 0
# error :  1 <- at epoch 79
# [0 0] 1
# error :  -1 <- at epoch 79
# [-1 -1] 0
# error :  -1 <- at epoch 80
# [-1 -1] -1
# error :  1 <- at epoch 80
# [-1  0] 0
# error :  1 <- at epoch 80
# [0 0] 1
# error :  -1 <- at epoch 80
# [-1 -1] 0
# error :  -1 <- at epoch 81
# [-1 -1] -1
# error :  1 <- at epoch 81
# [-1  0] 0
# error :  1 <- at epoch 81
# [0 0] 1
# error :  -1 <- at epoch 81
# [-1 -1] 0
# error :  -1 <- at epoch 82
# [-1 -1] -1
# error :  1 <- at epoch 82
# [-1  0] 0
# error :  1 <- at epoch 82
# [0 0] 1
# error :  -1 <- at epoch 82
# [-1 -1] 0
# error :  -1 <- at epoch 83
# [-1 -1] -1
# error :  1 <- at epoch 83
# [-1  0] 0
# error :  1 <- at epoch 83
# [0 0] 1
# error :  -1 <- at epoch 83
# [-1 -1] 0
# error :  -1 <- at epoch 84
# [-1 -1] -1
# error :  1 <- at epoch 84
# [-1  0] 0
# error :  1 <- at epoch 84
# [0 0] 1
# error :  -1 <- at epoch 84
# [-1 -1] 0
# error :  -1 <- at epoch 85
# [-1 -1] -1
# error :  1 <- at epoch 85
# [-1  0] 0
# error :  1 <- at epoch 85
# [0 0] 1
# error :  -1 <- at epoch 85
# [-1 -1] 0
# error :  -1 <- at epoch 86
# [-1 -1] -1
# error :  1 <- at epoch 86
# [-1  0] 0
# error :  1 <- at epoch 86
# [0 0] 1
# error :  -1 <- at epoch 86
# [-1 -1] 0
# error :  -1 <- at epoch 87
# [-1 -1] -1
# error :  1 <- at epoch 87
# [-1  0] 0
# error :  1 <- at epoch 87
# [0 0] 1
# error :  -1 <- at epoch 87
# [-1 -1] 0
# error :  -1 <- at epoch 88
# [-1 -1] -1
# error :  1 <- at epoch 88
# [-1  0] 0
# error :  1 <- at epoch 88
# [0 0] 1
# error :  -1 <- at epoch 88
# [-1 -1] 0
# error :  -1 <- at epoch 89
# [-1 -1] -1
# error :  1 <- at epoch 89
# [-1  0] 0
# error :  1 <- at epoch 89
# [0 0] 1
# error :  -1 <- at epoch 89
# [-1 -1] 0
# error :  -1 <- at epoch 90
# [-1 -1] -1
# error :  1 <- at epoch 90
# [-1  0] 0
# error :  1 <- at epoch 90
# [0 0] 1
# error :  -1 <- at epoch 90
# [-1 -1] 0
# error :  -1 <- at epoch 91
# [-1 -1] -1
# error :  1 <- at epoch 91
# [-1  0] 0
# error :  1 <- at epoch 91
# [0 0] 1
# error :  -1 <- at epoch 91
# [-1 -1] 0
# error :  -1 <- at epoch 92
# [-1 -1] -1
# error :  1 <- at epoch 92
# [-1  0] 0
# error :  1 <- at epoch 92
# [0 0] 1
# error :  -1 <- at epoch 92
# [-1 -1] 0
# error :  -1 <- at epoch 93
# [-1 -1] -1
# error :  1 <- at epoch 93
# [-1  0] 0
# error :  1 <- at epoch 93
# [0 0] 1
# error :  -1 <- at epoch 93
# [-1 -1] 0
# error :  -1 <- at epoch 94
# [-1 -1] -1
# error :  1 <- at epoch 94
# [-1  0] 0
# error :  1 <- at epoch 94
# [0 0] 1
# error :  -1 <- at epoch 94
# [-1 -1] 0
# error :  -1 <- at epoch 95
# [-1 -1] -1
# error :  1 <- at epoch 95
# [-1  0] 0
# error :  1 <- at epoch 95
# [0 0] 1
# error :  -1 <- at epoch 95
# [-1 -1] 0
# error :  -1 <- at epoch 96
# [-1 -1] -1
# error :  1 <- at epoch 96
# [-1  0] 0
# error :  1 <- at epoch 96
# [0 0] 1
# error :  -1 <- at epoch 96
# [-1 -1] 0
# error :  -1 <- at epoch 97
# [-1 -1] -1
# error :  1 <- at epoch 97
# [-1  0] 0
# error :  1 <- at epoch 97
# [0 0] 1
# error :  -1 <- at epoch 97
# [-1 -1] 0
# error :  -1 <- at epoch 98
# [-1 -1] -1
# error :  1 <- at epoch 98
# [-1  0] 0
# error :  1 <- at epoch 98
# [0 0] 1
# error :  -1 <- at epoch 98
# [-1 -1] 0
# error :  -1 <- at epoch 99
# [-1 -1] -1
# error :  1 <- at epoch 99
# [-1  0] 0
# error :  1 <- at epoch 99
# [0 0] 1
# error :  -1 <- at epoch 99
# [-1 -1] 0
